# %% [markdown]
# # 期末課題(問題4, 5, 6)

# %% [markdown]
# # 問題4・問題5
#
# 異なる培地・異なる温度で培養したある病原菌の大きさ(μm)を計測したところ、下表の様な結果が得られた。
#
# \begin{array}{cccc}  \hline
#  & 培地 & A & B & C \\ \hline
#   温度 & 30度 & 5 & 8 & 2  \\
#        & & 6 & 6 & 1 \\
#        & & 5 & 5 & 2 \\ \hline
#   温度 & 20度 & 3 & 5 & 3 \\
#        & & 2 & 3 & 4 \\
#        & & 2 & 2 & 5 \\ \hline
# \end{array}
#
# 病原菌の大きさに影響を与える要因を調べるために分散分析を行った。
#
# ## 問題4
#
# 以下の分散分析表を完成させ、$X$に入る値を答えよ。
#
# \begin{array}{c|cccc}  \hline
#  要因 & 平方和 & 自由度 & 平均平方 & F値 \\ \hline
#   培地 & ? & ? & ? & ? \\
#   温度 & ? & ? & ? & ? \\
#   培地\times 温度 & ? & X & ? & ? \\
#   誤差 & ? & ? & ? & \\ \hline
# \end{array}
#
# ## 問題5
#
# 分散分析の結果に基づいて、主効果と交互作用効果の検定結果を選択してください。

# %% [markdown]
# 問題4・5については、必要であれば下記のデータフレームを用いて計算してください。

# %%
size <- c(5,6,5,3,2,2,8,6,5,5,3,2,2,1,2,3,4,5)
medium <- factor(rep(c("A", "B", "C"), c(6, 6, 6)))
temperature <- factor(rep(rep(c("30", "20"), c(3, 3)), 3))
df <- data.frame(medium=medium, temperature=temperature, size=size)
df

# %%
# 必要があればコードを書いて計算してください。

# %% [markdown]
# # 問題6
#
# ある糸状菌を培養し、$1$ $mm^2$あたりの個体数を培養時間毎にカウントしたところ、下表の様な結果が得られた。
#
# \begin{array}{ccccc}  \hline
#  x(時間) & y(個体数) \\ \hline
#  0 & 100 \\
#  0.9 & 112 \\
#  2.2 & 132 \\
#  3.2 & 153 \\
#  4.3 & 174 \\
#  5.3 & 194 \\
#  6.2 & 226 \\
#  7.3 & 261 \\
#  8.3 & 279 \\
#  9.1 & 285 \\ \hline
# \end{array}
#
# 個体数$y$の経過時間$x$に対する回帰式$y=\beta_0 + \beta_1x$における$\beta_1$を推定し解答してください。

# %%
# 必要があればコードを書いて計算してください。
x <- c(0,0.9,2.2,3.2,4.3,5.3,6.2,7.3,8.3,9.1)
y <- c(100,112,132,153,174,194,226,261,279,285)
