# %% [markdown]
# # 第12回課題 教師なし学習

# %% [markdown]
# ## 課題1
#
# 下記コードでおなじみのペンギンのデータが読み込める。
#
# ペンギンのデータの3~6列目`data[,3:6]`を使用して、主成分分析を実施し、第1主成分でどれだけの情報が説明できるか記述してください。
#
# また、余裕があれば、第1主成分・第2主成分で散布図を描き、ペンギンの種で色分けして、身体の各部位の長さや重さに基づいた主成分分析によるグループ分けが、どの程度種の違いを反映しているか確認してみてください。

# %%
# ペンギンデータの読み込み
data <- read.csv("https://raw.githubusercontent.com/slt666666/biostatistics_text_wed/refs/heads/main/source/_static/data/chapter3_penguins.csv")

head(data)

# %%
# ここにコードの続きを書いて実行してください。

# %%
# 余裕があれば散布図も確認
library(ggplot2)

# %% [markdown]
# ## 課題2
#
# 課題1と同じデータセットで階層的クラスタリングを実施し、
#
# 作成した樹形図を基に３つのクラスターに分割してください。
#
# 身体の各部位の長さや重さに基づいて階層的クラスタリングにより分割した３つのクラスターが、どの程度ペンギンの種と一致しているか、下記コード等を用いて確認してください。
# ```
# table(data$species, clusters)
# ```

# %%
# ペンギンデータの読み込み
data <- read.csv("https://raw.githubusercontent.com/slt666666/biostatistics_text_wed/refs/heads/main/source/_static/data/chapter3_penguins.csv")

head(data)

# %%
# ここにコードの続きを書いて実行してください。
