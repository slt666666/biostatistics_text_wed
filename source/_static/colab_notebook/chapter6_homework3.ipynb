# %% [markdown]
# # 第8回 推定と検定 課題その3
#
# 以降の課題についてコードを書き、実行した結果をPandaのテスト・クイズページから記述してください。

# %% [markdown]
# ## 課題1
#
# 下のコードを動かすと、ペンギンの分類データを`df`として読み込めます。
#
# (データ元: https://allisonhorst.github.io/palmerpenguins/)
#
# データには3種のペンギン`Adelie`151個体、`Gentoo`123個体、`Chinstrap`68個体のデータが含まれている。
#
# `Adelie`種と`Gentoo`種の間で、くちばしの長さ`bill_length_mm`の平均値に差があるか検定を実施して結果を記述してください。
#
# 参考: `Adelie`種の全個体のくちばしの長さは`df[df$species == "Chinstrap","bill_length_mm"]`で取得できます。

# %%
df <- read.csv("https://raw.githubusercontent.com/slt666666/biostatistics_text_wed/refs/heads/main/source/_static/data/chapter3_penguins.csv")
head(df) # データの最初数行のみ表示

# %%
# ここにコードを書いて実行してください。

# %% [markdown]
# ## 課題2
#
# ある地域では、天気が雨の確率が10%、曇りの確率が20%、晴れの確率が70%とされている。
#
# この確率がどの程度当たるのか調べるために、30日間の天気を調査したところ、雨の日が5日間、曇りの日が5日間、晴れの日が20日間あった。
#
# この30日間の天気の観測結果は、もともと知られていた確率と適合しているか検定してください。

# %%
# ここにコードを書いて実行してください。

# %% [markdown]
# ## 課題3
#
# 飲酒習慣が血圧に与える影響を知るため、500人の飲酒習慣と血圧の値を調査した。
#
# その結果、
#
# \begin{array}{c|ccc|c}  \hline
#   習慣 & 正常血圧 & 異常血圧 &　計\\ \hline \hline
#   飲酒習慣あり & 124 & 163 & 287 \\
#   飲酒習慣無し & 104 & 109 & 213 \\ \hline
#   計 & 228 & 272 & 500 \\ \hline
# \end{array}
#
# という結果が得られた。
#
# この結果から、飲酒習慣と血圧の関係性が独立かそうでないかを検定し、結果を記述してください。

# %%
# ここにコードを書いて実行してください。
