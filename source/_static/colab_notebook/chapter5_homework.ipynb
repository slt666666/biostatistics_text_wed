# %% [markdown]
# # 第5回 標本分布 課題
#
# 以降の課題についてコードを書き、実行した結果をPandaのテスト・クイズページから記述してください。

# %% [markdown]
# ## 課題1
#
# あるクラスの数学の得点は平均$\mu = 65$点、標準偏差$\sigma = 10$の正規分布に従っている。
#
# このクラスにおいて、85点より高い点数の人は何%いるか計算してください。

# %%
# ここにコードを書いて実行してください。

# %% [markdown]
# ## 課題2
#
# とある地域に生息する生物は、$1/4096$の確率で通常の体色と異なる体色の形質を示す個体に遭遇することが知られている。
#
# 色違いの個体を捕獲するため、$10000$個体調査する計画を立てた。
#
# この時、色違いの個体に2個体遭遇出来る確率を、二項分布を用いた場合とポアソン分布を用いた場合をそれぞれ算出してみてください。

# %%
# ここにコードを書いて実行してください。

# %% [markdown]
# ## 課題3
#
# 課題2の調査において、
#
# $10000$個体調査した中で、何個体以上色違いの個体が見つかれば、5%未満の確率でしか起きない事象となるか算出してください。

# %%
# ここにコードを書いて実行してください。
