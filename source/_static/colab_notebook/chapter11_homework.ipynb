# %% [markdown]
# # 第13回課題 ベイズ統計学

# %% [markdown]
# ## 課題1
#
# あるお店では、農家A1から仕入れたトマトと、農家A2から仕入れたトマトを販売している。
#
# 販売しているトマトの内訳は、農家A1からが30%、農家A2 からが70%である。
#
# しかし、仕入れるトマトには一部規格外品が混ざっている。
#
# 農家A1のトマトは5%が規格外品で、農家A2のトマトは3%が規格外品である。
#
# ベイズの定理を用いて、「お店のトマトに不良品が見つかったとき、それが農家A1から仕入れたトマトである確率」を求めよ。
#
# $P(A_1|B) = \dfrac{P(B|A_1)P(A_1)}{P(B)}$

# %%
# 必要があればここにコードを書いて実行してください。
