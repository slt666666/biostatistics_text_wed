# %% [markdown]
# # 第9回 分散分析 課題
#
# 以降の課題についてコードを書き、実行した結果をPandaのテスト・クイズページから記述してください。

# %% [markdown]
# ## 課題1
#
# コメの系統A, B. Cの収穫量を調査するため、各系統5個体ずつ収穫量を調査した結果を下記コードで読み込む事が出来る。
#
# コメの系統によって収穫量に差があるか分散分析を用いて調べてください。
#
# また、もし系統によって差があった場合、どの系統間に差があると言えるか、調べてください。

# %%
df <- read.csv("https://raw.githubusercontent.com/slt666666/biostatistics_text_wed/refs/heads/main/source/_static/data/chapter7_hw1.csv")
df

# %%
# ここにコードを書いて実行してください。

# %% [markdown]
# ## 課題2
#
#
# コメの系統A, B. Cの収穫量と肥料の量の関係性を調査するため、各系統に対し肥料の量を3パターン(100,200,300)与えた際の収穫量を調査した結果を下記コードで読み込む事が出来る。
#
# コメの系統や肥料の量、その交互作用によって収穫量に差があるか分散分析を用いて調べてください。
#
# また交互作用効果が有意であった場合、どの様な差があると言えるか、多重比較または図などを描いてみて調べてください。

# %%
df <- read.csv("https://raw.githubusercontent.com/slt666666/biostatistics_text_wed/refs/heads/main/source/_static/data/chapter7_hw2.csv")
df

# %%
# ここにコードを書いて実行してください。
