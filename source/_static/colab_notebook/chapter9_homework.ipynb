# %% [markdown]
# # 第11回課題 一般化線形モデル

# %% [markdown]
# ## 課題1
#
# 下記コードで各日照条件`solar`と土壌水分量`water`における開花率のデータが読み込める。
#
# 開花率に対し、日照や土壌水分量がどの様に影響を与えているか調べたい。
#
# 一般化線形モデルを活用して、必要であればグラフ等も描き、調べた結果を述べてください。

# %%
# 各日照条件と土壌水分量における開花率のデータ
data <- read.csv("https://raw.githubusercontent.com/slt666666/biostatistics_text_wed/refs/heads/main/source/_static/data/chapter9_hw1.csv")
# データの一部を表示
head(data)

# %%
# ここにコードの続きを書いて実行してください。

result <- glm(cbind(flower, size - flower) ~ ????????, family = ??????, data = data)

# %% [markdown]
# ## 課題2
#
# 下記コードで、ある植物がある湿度`moisture`と気温`temperature`において、種子を何粒生成したか`seed_num`のデータが読み込める。
#
# 生成された種子数を説明するためのモデルを考えたときに、湿度`moisture`のみを考慮したモデルが良いか、気温`temperature`も考慮したモデルが良いか、
#
# ポアソン分布の一般化線形モデルを活用して、調べた結果を述べてください。

# %%
# 各湿度と気温における種子生成数のデータ
data <- read.csv("https://raw.githubusercontent.com/slt666666/biostatistics_text_wed/refs/heads/main/source/_static/data/chapter9_hw2.csv")
# データの一部を表示
head(data)

# %%
# ここにコードの続きを書いて実行してください。
