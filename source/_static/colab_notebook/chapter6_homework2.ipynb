# %% [markdown]
# # 第7回 推定と検定 課題その2
#
# 以降の課題についてコードを書き、実行した結果をPandaのテスト・クイズページから記述してください。

# %% [markdown]
# ## 課題1
#
# 東北地方のお米の主力品種である"ひとめぼれ"は1つの穂に平均110粒のお米がつく。
#
# K都大学に在籍する研究者T.S.氏は、このひとめぼれの収穫量を爆発的に増加させる研究を行っており、
#
# ゲノム解析に基づいて、ひとめぼれを改良した系統の開発に成功した。
#
# 改良した系統を2024年度に10個体植えた所、穂についたお米の数が、
#
# 172, 180, 216, 154, 192, 170, 168, 180, 156, 164粒であった。
#
# 改良された系統の1つの穂につくお米の数は、110粒より統計的に有意に高いか確かめたい。
#
# 帰無仮説:$H_0: \mu = 110$
#
# 対立仮説:$H_1: \mu > 110$
#
# として片側検定を実施し、$t$値と$p$値の計算結果と、検定の結果を記述してください。

# %%
# ここにコードを書いて実行してください。
data <- c(172, 180, 216, 154, 192, 170, 168, 180, 156, 164)
