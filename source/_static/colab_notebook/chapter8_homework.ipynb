# %% [markdown]
# # 第10回 回帰分析 課題
#
# 下のコードを動かすと、ペンギンの分類データを`df`として読み込めます。
#
# (データ元: https://allisonhorst.github.io/palmerpenguins/)
#
# このデータを用いて、以降の課題についてコードを書き、実行した結果から読み取れることをPandaのテスト・クイズページから記述してください。

# %%
df <- read.csv("https://raw.githubusercontent.com/slt666666/biostatistics_text_wed/refs/heads/main/source/_static/data/chapter3_penguins.csv")

head(df)

# %% [markdown]
# ## 課題1
#
# このデータフレームの`body_mass_g`(体重)を`bill_length_mm`(くちばしの長さ)で回帰した時、
#
# くちばしの長さが体重に与える影響が有意かどうか、体重はくちばしの長さで上手く説明できるかどうかを
#
# 回帰分析を実施して述べてください。

# %%
# ここにコードを書いて実行してください。

# %% [markdown]
# ## 課題2
#
# このデータフレームの`body_mass_g`(体重)を、`bill_length_mm`(くちばしの長さ)、`bill_depth_mm`(くちばしの奥行き)、`flipper_length_mm`(ヒレの長さ)で回帰した時、
#
# 体のどの部位が体重に影響を有意に与えているのか、また、３つの部位の情報で体重をうまく説明できているかを、重回帰分析を実施して述べてください。

# %%
# ここにコードを書いて実行してください。
